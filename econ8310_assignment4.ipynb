# %%
import pandas as pd

url = "https://github.com/dustywhite7/Econ8310/raw/master/AssignmentData/cookie_cats.csv"
df = pd.read_csv(url)

print(df.columns)

rresults = df.groupby("version")[["retention_1", "retention_7"]].mean().reset_index()
print(results)
# Out:
# Index(['userid', 'version', 'sum_gamerounds', 'retention_1', 'retention_7'], dtype='object')
#    version  retention_1  retention_7
# 0  gate_30     0.448188     0.190201
# 1  gate_40     0.442283     0.182000
